# %% [markdown]
# <img src="./images/DLI_Header.png" width=400/>

# %% [markdown]
# # Fundamentals of Accelerated Data Science #

# %% [markdown]
# ## 07 - Triton ##
#
# **Table of Contents**
# <br>
# This notebook covers the process of deploying a model with Triton Inference Server and walks through the various tools available within Triton. This notebook covers the below sections:
# 1. [Background](#s1)
# 2. [Preparing the Model](#s1)
#     * [Load the Model](#s1)
#     * [Creating the Folder Structure](#s1)
#     * [Creating the Configuration File](#s1)
# 3. [Loading the Model in Triton](#s1)
#     * [Starting Triton](#s1)
#     * [Check Status of Triton Server](#s1)
# 4. [Testing Inference](#s1)
#     * [Triton Client](#s1)
#     * [Verifying Results for Local Model and Triton](#s1)
# 5. [Analyzing Performance](#s1)
#     * [Customizing Perf Analyzer](#s1)
#     * [Exercise #1 - Testing Perf Analyzer](#s1)
# 6. [Model Analyzer](#s1)

# %% [markdown]
# # Background
# NVIDIA offers a framework for deploying ML models called Triton. Triton will automatically handle all inference requests that comes to the server. Triton supports multiple backends including PyTorch, TensorFlow, Forest Inference Library (FIL), etc. In this notebook, we will focus on the FIL backend using the xgboost model that was trained previously.

# %% [markdown]
# ## Preparing the Model
# ### Load the Model
# Let's start with loading the previous XGBoost model.

# %%
import xgboost as xgb
model = xgb.Booster({'nthread': 4})  # инициализация модели с использованием 4 потоков
model.load_model('xgboost_model.json')  # загрузка обученной модели в формате XGBoost

# %% [markdown]
# ### Creating the Folder Structure
# In the previous notebook, we just saved the XGBoost model to the working directory. Triton expects the model to be in a particular structure: Model name should be the top level directory, and the version number should be next. This allows for multiple models and versions of those models to be hosted simulatenously. Let's create that folder structure and save the model!

# %%
import os

# Create the model repository directory. The name of this directory is arbitrary.
REPO_PATH = os.path.abspath('models') # задаем путь для хранения моделей в Triton
os.makedirs(REPO_PATH, exist_ok=True) # создаем директорию (если не существует)

# The name of the model directory determines the name of the model as reported by Triton
model_dir = os.path.join(REPO_PATH, "virus_prediction")

# We can store multiple versions of the model in the same directory. In our case, we have just one version, so we will add a single directory, named '1'.
version_dir = os.path.join(model_dir, '1')
os.makedirs(version_dir, exist_ok=True)

# The default filename for XGBoost models saved in json format is 'xgboost.json'.
# It is recommended that you use this filename to avoid having to specify a name in the configuration file.
model_file = os.path.join(version_dir, 'xgboost.json')
model.save_model(model_file) # сохраняем модель в папке Triton.

# %% [markdown]
# ### Creating the Configuration File
# Triton also requires a configuration file that provides details about the model and deployment. For this notebook, we will assume default parameters.

# %%
config_text = f"""backend: "fil"
max_batch_size: 32768
input [                                 
 {{  
    name: "input__0" # имя входного тензора.
    data_type: TYPE_FP32
    dims: [ 4 ]     # размерность входа, здесь это массив из 4 чисел.                
  }} 
]
output [
 {{
    name: "output__0" 
    data_type: TYPE_FP32
    dims: [ 1 ]
  }}
]
instance_group [{{ kind: KIND_GPU }}] # модель будет запускаться на GPU
parameters [
  {{
    key: "model_type"
    value: {{ string_value: "xgboost_json" }} # тип модели
  }},
  {{
    key: "output_class"
    value: {{ string_value: "false" }} # false - чтобы выводить вероятности
  }},
  {{
    key: "storage_type"
    value: {{ string_value: "AUTO" }}
  }}
]

dynamic_batching {{
  max_queue_delay_microseconds: 100
}}"""
# max_queue_delay_microseconds- мин задержка в мкс для ожидания запроса в очереди перед созданием батча
config_path = os.path.join(model_dir, 'config.pbtxt')
with open(config_path, 'w') as file_:
    file_.write(config_text)

# %% [markdown]
# Now the model is ready to be loaded in Triton! The model repository should look like this.
#
# ```
# model/
# `-- virus_prediction
#     |-- 1
#     |   `-- xgboost.json
#     `-- config.pbtxt
# ```

# %% [markdown]
# ## Loading the Model in Triton
# Next, we will need to start the Triton server. For this course, the server has already been started, but we will briefly go the steps required.

# %% [markdown]
# ### Starting Triton
# Triton is available as buildable source code or a pre-built docker image. For simplicity, we recommend that most users start with the docker images. This is how you would start the docker container in the console.

# %%
#!docker run --gpus=1 --rm -p 8000:8000 -p 8001:8001 -p 8002:8002 -v /full/path/to/docs/examples/model_repository:/models nvcr.io/nvidia/tritonserver:<xx.yy>-py3 tritonserver --model-repository=/models

# %% [markdown]
# Wow! That's a lot of inputs. Let's break it down a little bit more.
#
# - **gpus=1** : Passes through the first GPU to the Triton Inference Server
# - **rm** : Removes the container after completing execution
# - **p 8000:8000** : Forwards the GTPCInferenceService Port
# - **p 8001:8001** : Forwards the HTTPService Port
# - **p 8002:8002** :  Forwards the Metrics Port
# - **v /full/path/to/docs/examples/model_repository:/models** : Mounts the path to the models folder on the host machine to the Triton Inference Server container
# - **nvcr.io/nvidia/tritonserver:<xx.yy>-py3** : Name of the Triton Inference Server image. The version number will change depending on the latest release
# - **tritonserver --model-repository=/models**: The command to run in the container. In this case, we start the Triton Inference Server and point to the models folder

# %% [markdown]
# Ух ты! Это много входных данных. Давайте разберем это еще немного.
#
# - **gpus=1**: проходит через первый графический процессор на сервер вывода Triton.
# - **rm** : удаляет контейнер после завершения выполнения.
# - **p 8000:8000**: перенаправляет порт GTPCInferenceService.
# - **p 8001:8001** : перенаправляет порт HTTPService.
# - **p 8002:8002** : пересылает порт метрик.
# - **v /full/path/to/docs/examples/model_repository:/models** : подключает путь к папке моделей на хост-компьютере к контейнеру Triton Inference Server.
# - **nvcr.io/nvidia/tritonserver:<xx.yy>-py3**: имя образа сервера вывода Triton. Номер версии изменится в зависимости от последней версии.
# - **tritonserver --model-repository=/models**: команда для запуска в контейнере. В этом случае мы запускаем сервер вывода Triton и указываем папку моделей.

# %% [markdown]
# As we mentioned before, the server has already been started for this lab. Let's check our connection to the server! We are using "triton" as the hostname because the default docker network will resolve "triton" to the ip address of the Triton Inference Server.

# %%
# !curl -v triton:8000/v2/health/ready
# Out:
# *   Trying 172.18.0.4:8000...
# * Connected to triton (172.18.0.4) port 8000 (#0)
# > GET /v2/health/ready HTTP/1.1
# > Host: triton:8000
# > User-Agent: curl/7.81.0
# > Accept: */*
# >
# * Mark bundle as not supporting multiuse
# < HTTP/1.1 200 OK
# < Content-Length: 0
# < Content-Type: text/plain
# <
# * Connection #0 to host triton left intact

# %% [markdown]
# Now let's see if the model has been loaded!

# %%
# !curl -X POST http://triton:8000/v2/repository/index
# Out:
# [{"name":"virus_prediction","version":"1","state":"READY"}]

# %% [markdown]
# If all went well, we should be able to see the model "virus prediction" show up as ready.

# %% [markdown]
# ## Testing Inference

# %% [markdown]
# ### Triton Client
# To test the deployment we will use the Triton Client library. Let's see how we can create an instance of the client.

# %%
import time
import tritonclient.grpc as triton_grpc
from tritonclient import utils as triton_utils
HOST = "triton"
PORT = 8001
TIMEOUT = 60

# %%
client = triton_grpc.InferenceServerClient(url=f'{HOST}:{PORT}')

# %% [markdown]
# Now let's make sure the Triton server is ready by sending a sample inference request. First let's load the training data. We will only load 32768 rows, as that's the max batch size we specified.

# %%
import cudf
import numpy as np
df = cudf.read_csv('./data/clean_uk_pop_full.csv', usecols=['age', 'sex', 'northing', 'easting', 'infected'], nrows=5000000)
df = df.sample(32768)
input_data = df.drop('infected', axis=1)
target = df[['infected']]
print(target)
# Out:
#          infected
# 1308835       0.0
# 2640997       0.0
# 2187451       0.0
# 2687898       0.0
# 1576458       0.0
# ...           ...
# 1693784       0.0
# 2565385       0.0
# 1434601       0.0
# 4517010       0.0
# 575866        0.0
#
# [32768 rows x 1 columns]

# %% [markdown]
# Now we convert it to a numpy array and force the type to be float32 (the same type we specified in the config file)

# %%
converted_df = input_data.to_numpy(dtype='float32')

# %% [markdown]
# Since we limited our batch size to 32768, let's splice the array and attempt the inference.

# %%
# %%time
batched_data = converted_df[:32768] # входные данные для предсказания
# Prepare the input tensor
input_tensor = triton_grpc.InferInput("input__0", batched_data.shape, 'FP32')
input_tensor.set_data_from_numpy(batched_data)

# Prepare the output
# Сообщается серверу, что на выходе нужно вернуть результат по имени "output0",
# это имя выходного тензора (определено в модели).
output = triton_grpc.InferRequestedOutput("output__0")

# Send inference request
# Серверу Triton отправляется запрос на выполнение предсказания.
response = client.infer("virus_prediction", [input_tensor], outputs=[output])
# 'virusprediction' — имя модели, к которой обращаемся.

# Get the output data
output_data = response.as_numpy("output__0")
# Out:
# CPU times: user 1.06 ms, sys: 4.44 ms, total: 5.5 ms
# Wall time: 8 ms

# %% [markdown]
# Let's make sure the results we got were the same as with the local model.

# %%
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

xgb_data = xgb.DMatrix(input_data)
y_test = model.predict(xgb_data)

# %%
# Check that we got the same accuracy as previously
#target = target.to_numpy()
import matplotlib.pyplot as plt

false_pos_rate, true_pos_rate, thresholds = roc_curve(target.to_numpy(), y_test)
auc_result = auc(false_pos_rate, true_pos_rate)

fig, ax = plt.subplots(figsize=(5, 5))
ax.plot(false_pos_rate, true_pos_rate, lw=3,
        label='AUC = {:.2f}'.format(auc_result))
ax.plot([0, 1], [0, 1], 'k--', lw=2)
ax.set(
    xlim=(0, 1),
    ylim=(0, 1),
    title="ROC Curve",
    xlabel="False Positive Rate",
    ylabel="True Positive Rate",
)
ax.legend(loc='lower right');
plt.show()

# %%
# Check that we got the same accuracy as previously
#target = target.to_numpy()
import matplotlib.pyplot as plt

false_pos_rate, true_pos_rate, thresholds = roc_curve(target.to_numpy(), output_data)
auc_result = auc(false_pos_rate, true_pos_rate)

fig, ax = plt.subplots(figsize=(5, 5))
ax.plot(false_pos_rate, true_pos_rate, lw=3,
        label='AUC = {:.2f}'.format(auc_result))
ax.plot([0, 1], [0, 1], 'k--', lw=2)
ax.set(
    xlim=(0, 1),
    ylim=(0, 1),
    title="ROC Curve",
    xlabel="False Positive Rate",
    ylabel="True Positive Rate",
)
ax.legend(loc='lower right');
plt.show()

# %% [markdown]
# As we can see, our AUC score is the same between both inference options!

# %% [markdown]
# ## Analyzing Performance

# %% [markdown]
# Earlier, we tested a *relatively* small inference request. What if we want to see the max throughput of the model? Luckily, Triton offers a performance analysis tool that generates synthetic data to collect latency and throughput numbers. Let's try it out.

# %% [markdown]
# Ранее мы тестировали *относительно* небольшой запрос вывода. Что, если мы хотим увидеть максимальную пропускную способность модели? К счастью, Triton предлагает инструмент анализа производительности, который генерирует синтетические данные для сбора показателей задержки и пропускной способности. Давайте попробуем.

# %%
# !perf_analyzer -m virus_prediction -u "triton:8000"
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average latency and throughput
#   Measurement window: 5000 msec
#   Using synchronous calls for inference
#
# Request concurrency: 1
#   Client:
#     Request count: 41428
#     Throughput: 2294.07 infer/sec
#     Avg latency: 432 usec (standard deviation 108 usec)
#     p50 latency: 419 usec
#     p90 latency: 580 usec
#     p95 latency: 622 usec
#     p99 latency: 688 usec
#     Avg HTTP time: 427 usec (send/recv 44 usec + response wait 383 usec)
#   Server:
#     Inference count: 41430
#     Execution count: 41430
#     Successful request count: 41430
#     Avg request latency: 278 usec (overhead 1 usec + queue 193 usec + compute input 21 usec + compute infer 44 usec + compute output 18 usec)
#
# Inferences/Second vs. Client Average Batch Latency
# Concurrency: 1, throughput: 2294.07 infer/sec, latency 432 usec

# %% [markdown]
# That's a lot of information to take in. Let's break it down.
#
# **Measurement window**: Timeframe that measurements are taken in
#
# **Batch Size**: Number of inputs in each request
#
#
# **Concurrency**: Number of simulatenous connections
# **Latency**: Time taken to recieve results
# **p50/90/95/99**: Different percentiles for latency
#
# Based on these results, we can see that our throughput is roughly ~2300 inferences per second with a single concurrent connection, and the average latency for each requst is 434 usec.

# %% [markdown]
# Это очень много информации, которую нужно усвоить. Давайте разберем ее по частям.
#
# **Окно измерений**: временной интервал, в течение которого проводятся измерения.
#
# **Размер пакета**: количество входных данных в каждом запросе.
#
#
# **Параллелизм**: количество одновременных подключений.
# **Задержка**: время, необходимое для получения результатов.
# **p50/90/95/99**: разные процентили задержки.
#
# Основываясь на этих результатах, мы видим, что наша пропускная способность составляет примерно ~ 2300 выводов в секунду при одном одновременном соединении, а средняя задержка для каждого запроса составляет 434 мкс.

# %% [markdown]
# # Customizing Perf Analyzer
# The Performance Analyzer tool for Triton has many knobs that can be turned to analyze results. Let's enable GPU metric collection, and increase the batch size and concurrency range values!

# %% [markdown]
# Инструмент «Анализатор производительности» для Triton имеет множество ручек, которые можно поворачивать для анализа результатов. Давайте включим сбор показателей графического процессора и увеличим размер пакета и диапазон параллелизма!

# %%
# !perf_analyzer --collect-metrics -m virus_prediction -u "triton:8000" -b 8 --concurrency-range 2:8:2
# Out:
# *** Measurement Settings ***
#   Batch size: 8
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average latency and throughput
#   Measurement window: 5000 msec
#   Latency limit: 0 msec
#   Concurrency limit: 8 concurrent requests
#   Using synchronous calls for inference
#
# Request concurrency: 2
#   Client:
#     Request count: 80553
#     Throughput: 35509.4 infer/sec
#     Avg latency: 447 usec (standard deviation 108 usec)
#     p50 latency: 427 usec
#     p90 latency: 610 usec
#     p95 latency: 652 usec
#     p99 latency: 711 usec
#     Avg HTTP time: 443 usec (send/recv 41 usec + response wait 402 usec)
#   Server:
#     Inference count: 644440
#     Execution count: 40348
#     Successful request count: 80555
#     Avg request latency: 287 usec (overhead 2 usec + queue 186 usec + compute input 25 usec + compute infer 46 usec + compute output 27 usec)
#
#   Server Prometheus Metrics:
#     Avg GPU Utilization:
#       GPU-2802f26d-58d1-d7fd-ed33-01fd715dbd21 : 1%
#       GPU-51eece2e-8d9a-74ae-c4b5-f115199a3fb2 : 1%
#       GPU-5ff35893-8fdc-d76b-ead4-0c72126f08d4 : 1%
#       GPU-8cf674e3-b9db-4bc9-88f2-ed21536ea65d : 1%
#     Avg GPU Power Usage:
#       GPU-2802f26d-58d1-d7fd-ed33-01fd715dbd21 : 28.191 watts
#       GPU-51eece2e-8d9a-74ae-c4b5-f115199a3fb2 : 28.0577 watts
#       GPU-5ff35893-8fdc-d76b-ead4-0c72126f08d4 : 26.0742 watts
#       GPU-8cf674e3-b9db-4bc9-88f2-ed21536ea65d : 27.8506 watts
#     Max GPU Memory Usage:
#       GPU-2802f26d-58d1-d7fd-ed33-01fd715dbd21 : 230686720 bytes
#       GPU-51eece2e-8d9a-74ae-c4b5-f115199a3fb2 : 832569344 bytes
#       GPU-5ff35893-8fdc-d76b-ead4-0c72126f08d4 : 230686720 bytes
#       GPU-8cf674e3-b9db-4bc9-88f2-ed21536ea65d : 230686720 bytes
#     Total GPU Memory:
#       GPU-2802f26d-58d1-d7fd-ed33-01fd715dbd21 : 16106127360 bytes
#       GPU-51eece2e-8d9a-74ae-c4b5-f115199a3fb2 : 16106127360 bytes
#       GPU-5ff35893-8fdc-d76b-ead4-0c72126f08d4 : 16106127360 bytes
#       GPU-8cf674e3-b9db-4bc9-88f2-ed21536ea65d : 16106127360 bytes
# Request concurrency: 4
#   Client:
#     Request count: 175807
#     Throughput: 76400.3 infer/sec
#     Avg latency: 415 usec (standard deviation 98 usec)
#     p50 latency: 383 usec
#     p90 latency: 559 usec
#     p95 latency: 618 usec
#     p99 latency: 697 usec
#     Avg HTTP time: 411 usec (send/recv 38 usec + response wait 373 usec)
#   Server:
#     Inference count: 1406480
#     Execution count: 44402
#     Successful request count: 175810
#     Avg request latency: 276 usec (overhead 1 usec + queue 168 usec + compute input 24 usec + compute infer 45 usec + compute output 37 usec)
#
#   Server Prometheus Metrics:
#     Avg GPU Utilization:
#       GPU-2802f26d-58d1-d7fd-ed33-01fd715dbd21 : 1%
#       GPU-51eece2e-8d9a-74ae-c4b5-f115199a3fb2 : 1%
#       GPU-5ff35893-8fdc-d76b-ead4-0c72126f08d4 : 1%
#       GPU-8cf674e3-b9db-4bc9-88f2-ed21536ea65d : 1%
#     Avg GPU Power Usage:
#       GPU-2802f26d-58d1-d7fd-ed33-01fd715dbd21 : 28.1568 watts
#       GPU-51eece2e-8d9a-74ae-c4b5-f115199a3fb2 : 28.0074 watts
#       GPU-5ff35893-8fdc-d76b-ead4-0c72126f08d4 : 26.0668 watts
#       GPU-8cf674e3-b9db-4bc9-88f2-ed21536ea65d : 27.8405 watts
#     Max GPU Memory Usage:
#       GPU-2802f26d-58d1-d7fd-ed33-01fd715dbd21 : 230686720 bytes
#       GPU-51eece2e-8d9a-74ae-c4b5-f115199a3fb2 : 832569344 bytes
#       GPU-5ff35893-8fdc-d76b-ead4-0c72126f08d4 : 230686720 bytes
#       GPU-8cf674e3-b9db-4bc9-88f2-ed21536ea65d : 230686720 bytes
#     Total GPU Memory:
#       GPU-2802f26d-58d1-d7fd-ed33-01fd715dbd21 : 16106127360 bytes
#       GPU-51eece2e-8d9a-74ae-c4b5-f115199a3fb2 : 16106127360 bytes
#       GPU-5ff35893-8fdc-d76b-ead4-0c72126f08d4 : 16106127360 bytes
#       GPU-8cf674e3-b9db-4bc9-88f2-ed21536ea65d : 16106127360 bytes
# Request concurrency: 6
#   Client:
#     Request count: 333949
#     Throughput: 138845 infer/sec
#     Avg latency: 342 usec (standard deviation 75 usec)
#     p50 latency: 342 usec
#     p90 latency: 397 usec
#     p95 latency: 435 usec
#     p99 latency: 587 usec
#     Avg HTTP time: 339 usec (send/recv 31 usec + response wait 308 usec)
#   Server:
#     Inference count: 2671584
#     Execution count: 93639
#     Successful request count: 333948
#     Avg request latency: 210 usec (overhead 2 usec + queue 126 usec + compute input 16 usec + compute infer 37 usec + compute output 28 usec)
#
#   Server Prometheus Metrics:
#     Avg GPU Utilization:
#       GPU-2802f26d-58d1-d7fd-ed33-01fd715dbd21 : 2%
#       GPU-51eece2e-8d9a-74ae-c4b5-f115199a3fb2 : 2%
#       GPU-5ff35893-8fdc-d76b-ead4-0c72126f08d4 : 2.1%
#       GPU-8cf674e3-b9db-4bc9-88f2-ed21536ea65d : 2%
#     Avg GPU Power Usage:
#       GPU-2802f26d-58d1-d7fd-ed33-01fd715dbd21 : 28.2001 watts
#       GPU-51eece2e-8d9a-74ae-c4b5-f115199a3fb2 : 28.0268 watts
#       GPU-5ff35893-8fdc-d76b-ead4-0c72126f08d4 : 26.0841 watts
#       GPU-8cf674e3-b9db-4bc9-88f2-ed21536ea65d : 27.8384 watts
#     Max GPU Memory Usage:
#       GPU-2802f26d-58d1-d7fd-ed33-01fd715dbd21 : 230686720 bytes
#       GPU-51eece2e-8d9a-74ae-c4b5-f115199a3fb2 : 832569344 bytes
#       GPU-5ff35893-8fdc-d76b-ead4-0c72126f08d4 : 230686720 bytes
#       GPU-8cf674e3-b9db-4bc9-88f2-ed21536ea65d : 230686720 bytes
#     Total GPU Memory:
#       GPU-2802f26d-58d1-d7fd-ed33-01fd715dbd21 : 16106127360 bytes
#       GPU-51eece2e-8d9a-74ae-c4b5-f115199a3fb2 : 16106127360 bytes
#       GPU-5ff35893-8fdc-d76b-ead4-0c72126f08d4 : 16106127360 bytes
#       GPU-8cf674e3-b9db-4bc9-88f2-ed21536ea65d : 16106127360 bytes
# Request concurrency: 8
#   Client:
#     Request count: 502439
#     Throughput: 182904 infer/sec
#     Avg latency: 346 usec (standard deviation 63 usec)
#     p50 latency: 351 usec
#     p90 latency: 384 usec
#     p95 latency: 396 usec
#     p99 latency: 436 usec
#     Avg HTTP time: 343 usec (send/recv 32 usec + response wait 311 usec)
#   Server:
#     Inference count: 4019520
#     Execution count: 121468
#     Successful request count: 502440
#     Avg request latency: 194 usec (overhead 0 usec + queue 119 usec + compute input 14 usec + compute infer 34 usec + compute output 25 usec)
#
#   Server Prometheus Metrics:
#     Avg GPU Utilization:
#       GPU-2802f26d-58d1-d7fd-ed33-01fd715dbd21 : 3%
#       GPU-51eece2e-8d9a-74ae-c4b5-f115199a3fb2 : 3%
#       GPU-5ff35893-8fdc-d76b-ead4-0c72126f08d4 : 3%
#       GPU-8cf674e3-b9db-4bc9-88f2-ed21536ea65d : 3%
#     Avg GPU Power Usage:
#       GPU-2802f26d-58d1-d7fd-ed33-01fd715dbd21 : 28.214 watts
#       GPU-51eece2e-8d9a-74ae-c4b5-f115199a3fb2 : 28.0612 watts
#       GPU-5ff35893-8fdc-d76b-ead4-0c72126f08d4 : 26.0888 watts
#       GPU-8cf674e3-b9db-4bc9-88f2-ed21536ea65d : 27.8615 watts
#     Max GPU Memory Usage:
#       GPU-2802f26d-58d1-d7fd-ed33-01fd715dbd21 : 230686720 bytes
#       GPU-51eece2e-8d9a-74ae-c4b5-f115199a3fb2 : 832569344 bytes
#       GPU-5ff35893-8fdc-d76b-ead4-0c72126f08d4 : 230686720 bytes
#       GPU-8cf674e3-b9db-4bc9-88f2-ed21536ea65d : 230686720 bytes
#     Total GPU Memory:
#       GPU-2802f26d-58d1-d7fd-ed33-01fd715dbd21 : 16106127360 bytes
#       GPU-51eece2e-8d9a-74ae-c4b5-f115199a3fb2 : 16106127360 bytes
#       GPU-5ff35893-8fdc-d76b-ead4-0c72126f08d4 : 16106127360 bytes
#       GPU-8cf674e3-b9db-4bc9-88f2-ed21536ea65d : 16106127360 bytes
# Inferences/Second vs. Client Average Batch Latency
# Concurrency: 2, throughput: 35509.4 infer/sec, latency 447 usec
# Concurrency: 4, throughput: 76400.3 infer/sec, latency 415 usec
# Concurrency: 6, throughput: 138845 infer/sec, latency 342 usec
# Concurrency: 8, throughput: 182904 infer/sec, latency 346 usec

# %% [markdown]
# The results show that our model configuration gives a throughput of about ~156171 inferences per second. Notice how there are significant throughput gains as we increase the number of concurrent connections. With low concurrency values, Triton is idle during the time when the response is returned to the client and the next request is received at the server. Throughput increases when we increase concurrency values because Triton overlaps the processing of one request with the communication of the other.

# %% [markdown]
# Результаты показывают, что наша конфигурация модели обеспечивает пропускную способность около 156 171 выводов в секунду. Обратите внимание, насколько значительно увеличивается пропускная способность при увеличении количества одновременных подключений. При низких значениях параллелизма Triton простаивает в то время, когда ответ возвращается клиенту и поступает следующий запрос на сервер. Пропускная способность увеличивается, когда мы увеличиваем значения параллелизма, поскольку Triton перекрывает обработку одного запроса с передачей другого.

# %% [markdown]
# # Exercise
# Please take this time to experiment with the perf analyzer tool. A full list of parameters can be seen with the --help argument. Some parameters that we recommend trying out are listed below:
# * -b <value> : batch size
# * --concurrency-range <start:end:step> : range of concurrency values to test
# * --collect-metrics : enable collection of GPU metrics

# %% [markdown]
# Пожалуйста, найдите время, чтобы поэкспериментировать с инструментом анализатора производительности. Полный список параметров можно увидеть с помощью аргумента --help. Некоторые параметры, которые мы рекомендуем попробовать, перечислены ниже:
# * -b <значение>: размер пакета
# * --concurrency-range <start:end:step> : диапазон значений параллелизма для проверки
# * --collect-metrics: включить сбор показателей графического процессора.

# %%
# !perf_analyzer --collect-metrics -m virus_prediction -u "triton:8000" -b 8 --concurrency-range 2:8:2
# Out:
# *** Measurement Settings ***
#   Batch size: 8
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average latency and throughput
#   Measurement window: 5000 msec
#   Latency limit: 0 msec
#   Concurrency limit: 8 concurrent requests
#   Using synchronous calls for inference
#
# Request concurrency: 2
#   Client:
#     Request count: 78778
#     Throughput: 34756.1 infer/sec
#     Avg latency: 456 usec (standard deviation 111 usec)
#     p50 latency: 429 usec
#     p90 latency: 609 usec
#     p95 latency: 677 usec
#     p99 latency: 698 usec
#     Avg HTTP time: 452 usec (send/recv 44 usec + response wait 408 usec)
#   Server:
#     Inference count: 630256
#     Execution count: 39455
#     Successful request count: 78782
#     Avg request latency: 316 usec (overhead 1 usec + queue 208 usec + compute input 27 usec + compute infer 49 usec + compute output 30 usec)
#
#   Server Prometheus Metrics:
#     Avg GPU Utilization:
#       GPU-2802f26d-58d1-d7fd-ed33-01fd715dbd21 : 0.894737%
#       GPU-51eece2e-8d9a-74ae-c4b5-f115199a3fb2 : 0.894737%
#       GPU-5ff35893-8fdc-d76b-ead4-0c72126f08d4 : 0.894737%
#       GPU-8cf674e3-b9db-4bc9-88f2-ed21536ea65d : 0.894737%
#     Avg GPU Power Usage:
#       GPU-2802f26d-58d1-d7fd-ed33-01fd715dbd21 : 28.1882 watts
#       GPU-51eece2e-8d9a-74ae-c4b5-f115199a3fb2 : 28.021 watts
#       GPU-5ff35893-8fdc-d76b-ead4-0c72126f08d4 : 26.063 watts
#       GPU-8cf674e3-b9db-4bc9-88f2-ed21536ea65d : 27.8324 watts
#     Max GPU Memory Usage:
#       GPU-2802f26d-58d1-d7fd-ed33-01fd715dbd21 : 230686720 bytes
#       GPU-51eece2e-8d9a-74ae-c4b5-f115199a3fb2 : 832569344 bytes
#       GPU-5ff35893-8fdc-d76b-ead4-0c72126f08d4 : 230686720 bytes
#       GPU-8cf674e3-b9db-4bc9-88f2-ed21536ea65d : 230686720 bytes
#     Total GPU Memory:
#       GPU-2802f26d-58d1-d7fd-ed33-01fd715dbd21 : 16106127360 bytes
#       GPU-51eece2e-8d9a-74ae-c4b5-f115199a3fb2 : 16106127360 bytes
#       GPU-5ff35893-8fdc-d76b-ead4-0c72126f08d4 : 16106127360 bytes
#       GPU-8cf674e3-b9db-4bc9-88f2-ed21536ea65d : 16106127360 bytes
# Request concurrency: 4
#   Client:
#     Request count: 164541
#     Throughput: 71734.7 infer/sec
#     Avg latency: 443 usec (standard deviation 101 usec)
#     p50 latency: 431 usec
#     p90 latency: 603 usec
#     p95 latency: 656 usec
#     p99 latency: 705 usec
#     Avg HTTP time: 439 usec (send/recv 37 usec + response wait 402 usec)
#   Server:
#     Inference count: 1316336
#     Execution count: 41665
#     Successful request count: 164542
#     Avg request latency: 302 usec (overhead 1 usec + queue 185 usec + compute input 28 usec + compute infer 48 usec + compute output 39 usec)
#
#   Server Prometheus Metrics:
#     Avg GPU Utilization:
#       GPU-2802f26d-58d1-d7fd-ed33-01fd715dbd21 : 1%
#       GPU-51eece2e-8d9a-74ae-c4b5-f115199a3fb2 : 1%
#       GPU-5ff35893-8fdc-d76b-ead4-0c72126f08d4 : 1%
#       GPU-8cf674e3-b9db-4bc9-88f2-ed21536ea65d : 1%
#     Avg GPU Power Usage:
#       GPU-2802f26d-58d1-d7fd-ed33-01fd715dbd21 : 28.1366 watts
#       GPU-51eece2e-8d9a-74ae-c4b5-f115199a3fb2 : 28.0313 watts
#       GPU-5ff35893-8fdc-d76b-ead4-0c72126f08d4 : 26.0631 watts
#       GPU-8cf674e3-b9db-4bc9-88f2-ed21536ea65d : 27.8366 watts
#     Max GPU Memory Usage:
#       GPU-2802f26d-58d1-d7fd-ed33-01fd715dbd21 : 230686720 bytes
#       GPU-51eece2e-8d9a-74ae-c4b5-f115199a3fb2 : 832569344 bytes
#       GPU-5ff35893-8fdc-d76b-ead4-0c72126f08d4 : 230686720 bytes
#       GPU-8cf674e3-b9db-4bc9-88f2-ed21536ea65d : 230686720 bytes
#     Total GPU Memory:
#       GPU-2802f26d-58d1-d7fd-ed33-01fd715dbd21 : 16106127360 bytes
#       GPU-51eece2e-8d9a-74ae-c4b5-f115199a3fb2 : 16106127360 bytes
#       GPU-5ff35893-8fdc-d76b-ead4-0c72126f08d4 : 16106127360 bytes
#       GPU-8cf674e3-b9db-4bc9-88f2-ed21536ea65d : 16106127360 bytes
# Request concurrency: 6
#   Client:
#     Request count: 254606
#     Throughput: 108265 infer/sec
#     Avg latency: 440 usec (standard deviation 102 usec)
#     p50 latency: 434 usec
#     p90 latency: 596 usec
#     p95 latency: 655 usec
#     p99 latency: 718 usec
#     Avg HTTP time: 436 usec (send/recv 37 usec + response wait 399 usec)
#   Server:
#     Inference count: 2036816
#     Execution count: 43743
#     Successful request count: 254602
#     Avg request latency: 313 usec (overhead 1 usec + queue 182 usec + compute input 28 usec + compute infer 50 usec + compute output 51 usec)
#
#   Server Prometheus Metrics:
#     Avg GPU Utilization:
#       GPU-2802f26d-58d1-d7fd-ed33-01fd715dbd21 : 1.10526%
#       GPU-51eece2e-8d9a-74ae-c4b5-f115199a3fb2 : 1.10526%
#       GPU-5ff35893-8fdc-d76b-ead4-0c72126f08d4 : 1%
#       GPU-8cf674e3-b9db-4bc9-88f2-ed21536ea65d : 1%
#     Avg GPU Power Usage:
#       GPU-2802f26d-58d1-d7fd-ed33-01fd715dbd21 : 28.1418 watts
#       GPU-51eece2e-8d9a-74ae-c4b5-f115199a3fb2 : 28.0313 watts
#       GPU-5ff35893-8fdc-d76b-ead4-0c72126f08d4 : 26.063 watts
#       GPU-8cf674e3-b9db-4bc9-88f2-ed21536ea65d : 27.8469 watts
#     Max GPU Memory Usage:
#       GPU-2802f26d-58d1-d7fd-ed33-01fd715dbd21 : 230686720 bytes
#       GPU-51eece2e-8d9a-74ae-c4b5-f115199a3fb2 : 832569344 bytes
#       GPU-5ff35893-8fdc-d76b-ead4-0c72126f08d4 : 230686720 bytes
#       GPU-8cf674e3-b9db-4bc9-88f2-ed21536ea65d : 230686720 bytes
#     Total GPU Memory:
#       GPU-2802f26d-58d1-d7fd-ed33-01fd715dbd21 : 16106127360 bytes
#       GPU-51eece2e-8d9a-74ae-c4b5-f115199a3fb2 : 16106127360 bytes
#       GPU-5ff35893-8fdc-d76b-ead4-0c72126f08d4 : 16106127360 bytes
#       GPU-8cf674e3-b9db-4bc9-88f2-ed21536ea65d : 16106127360 bytes
# Request concurrency: 8
#   Client:
#     Request count: 409676
#     Throughput: 161328 infer/sec
#     Avg latency: 393 usec (standard deviation 94 usec)
#     p50 latency: 356 usec
#     p90 latency: 487 usec
#     p95 latency: 581 usec
#     p99 latency: 715 usec
#     Avg HTTP time: 390 usec (send/recv 34 usec + response wait 356 usec)
#   Server:
#     Inference count: 3277432
#     Execution count: 68048
#     Successful request count: 409679
#     Avg request latency: 270 usec (overhead 1 usec + queue 151 usec + compute input 22 usec + compute infer 45 usec + compute output 50 usec)
#
#   Server Prometheus Metrics:
#     Avg GPU Utilization:
#       GPU-2802f26d-58d1-d7fd-ed33-01fd715dbd21 : 1.5%
#       GPU-51eece2e-8d9a-74ae-c4b5-f115199a3fb2 : 1.59091%
#       GPU-5ff35893-8fdc-d76b-ead4-0c72126f08d4 : 1.77273%
#       GPU-8cf674e3-b9db-4bc9-88f2-ed21536ea65d : 1.68182%
#     Avg GPU Power Usage:
#       GPU-2802f26d-58d1-d7fd-ed33-01fd715dbd21 : 28.1828 watts
#       GPU-51eece2e-8d9a-74ae-c4b5-f115199a3fb2 : 28.0301 watts
#       GPU-5ff35893-8fdc-d76b-ead4-0c72126f08d4 : 26.063 watts
#       GPU-8cf674e3-b9db-4bc9-88f2-ed21536ea65d : 27.8462 watts
#     Max GPU Memory Usage:
#       GPU-2802f26d-58d1-d7fd-ed33-01fd715dbd21 : 230686720 bytes
#       GPU-51eece2e-8d9a-74ae-c4b5-f115199a3fb2 : 832569344 bytes
#       GPU-5ff35893-8fdc-d76b-ead4-0c72126f08d4 : 230686720 bytes
#       GPU-8cf674e3-b9db-4bc9-88f2-ed21536ea65d : 230686720 bytes
#     Total GPU Memory:
#       GPU-2802f26d-58d1-d7fd-ed33-01fd715dbd21 : 16106127360 bytes
#       GPU-51eece2e-8d9a-74ae-c4b5-f115199a3fb2 : 16106127360 bytes
#       GPU-5ff35893-8fdc-d76b-ead4-0c72126f08d4 : 16106127360 bytes
#       GPU-8cf674e3-b9db-4bc9-88f2-ed21536ea65d : 16106127360 bytes
# Inferences/Second vs. Client Average Batch Latency
# Concurrency: 2, throughput: 34756.1 infer/sec, latency 456 usec
# Concurrency: 4, throughput: 71734.7 infer/sec, latency 443 usec
# Concurrency: 6, throughput: 108265 infer/sec, latency 440 usec
# Concurrency: 8, throughput: 161328 infer/sec, latency 393 usec

# %% [markdown]
# ## Model Analyzer
# Although it is out of scope for this course, we would like to introduce the Model Analyzer tool that is available as part of Triton. This tool searches through different parameter configurations to find optimal parameters that maximize inference throughput. With some minor processing, results can be viewed in a PDF format as well. An example of the output is shown below. More information about the Model Analyzer can be found [here](https://docs.nvidia.com/deeplearning/triton-inference-server/user-guide/docs/user_guide/model_analyzer.html).

# %% [markdown]
# ![image](images/model_analyzer.png)

# %%
import IPython
app = IPython.Application.instance()
app.kernel.do_shutdown(True)
# Out:
# {'status': 'ok', 'restart': True}

# %% [markdown]
# **Well Done!** Let's move to the [next notebook](3-08_k-means_dask.ipynb).

# %% [markdown]
# <img src="./images/DLI_Header.png" width=400/>
